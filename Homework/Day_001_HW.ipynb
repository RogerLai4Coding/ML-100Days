# %% [markdown]
# ### 作業1
# #### 我所選擇的題目為 Kaggle Competitions 上利用新聞去預測股票動態( [Using News to Predict Stock Movements](https://www.kaggle.com/c/two-sigma-financial-news) )：
# 1. 若是成功找出藉由新聞預測股票動態的方式，投資人將能更容易遇測、影響，甚至控制股票市場，對經濟有相當程度的影響。
# 2. 資料是由Intrinio提供市場資料，及Thomson Reuters提供新聞內容。
# 3. 資料皆為結構化的數值及表格。
# 4. 從原始資料中得到假設之後，搜集新的新聞數據，用同一套假設去預測接下來的動態，再比較預測結果與實際動態之間的差異。

# %% [markdown]
# ### 作業2
# 1. 業績與司機性質與行為之間的關係。
# 2. 資料為每個司機每天的業績，與司機的個人資料、個性、對乘客的態度及反應、開車習慣等等，以及司機當天的狀態表現。資料為司機本人、司機主管、乘客提供。
# 3. 資料皆為結構化的數值及表格。
# 4. 驗證得到預測最佳業績的司機性質、行為組合之後，招募類似性質的司機或調整司機呈現類似性質，並與其他的司機進行業績上的比較。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y - y_hat)*(y-y_hat)) / len(y)
    return mse

def mean_absolute_error(y, y_hat):
    mae = sum(abs(y - y_hat)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 195.591
# The Mean absolute error is 11.517
